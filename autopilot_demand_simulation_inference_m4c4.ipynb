# %% [markdown]
# # Water Demand Prediction with Amazon SageMaker Autopilot

# %% [markdown]
# ---
#
# This notebook's CI test result for ap-southeast-2 is as follows. CI test results in other regions can be found at the end of the notebook.
#
# ![This us-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-west-2/autopilot|autopilot_california_housing.ipynb)
#
# ---

# %% [markdown]
# _**Using Autopilot to Predict House Prices in California**_
#
#
# Kernel `Python 3 (Data Science)` works well with this notebook. You will have the best experience running this within SageMaker Studio.
#
# ---
#
# ## Contents
#
# 1. [Introduction](#Introduction)
# 1. [Setup](#Setup)
# 1. [Prepare Training Data](#Data)
# 1. [Train](#Settingup)
# 1. [Autopilot Results](#Results)
# 1. [Evaluate Using Test Data](#Evaluate)
# 1. [Cleanup](#Cleanup)
#
#
# ---
#
# ## Introduction
#
# Amazon SageMaker Autopilot is an automated machine learning (commonly referred to as AutoML) solution for tabular datasets. You can use SageMaker Autopilot in different ways: on autopilot (without any human input) or with human guidance, without code through SageMaker Studio or scripted using the AWS SDKs. This notebook will use the AWS SDKs to simply create and deploy a machine learning model without doing any feature engineering manually. We will also explore the auto-generated feature importance report.
#
# Demand modelling is done per location. Features for demand forecasting:
#
# * ```doy```
# * ```Aquifer```
# * ```PE```
# * ```month```
# * ```mday```
# * ```is_holiday```
# * ```wday```
# * ```API```
# * ```lagAPI```
# * ```Tmax```
# * ```Tmaxlag1```
# * ```Sun```
# * ```Sunlag1```
# * ```WVRain```
# * ```KerburnRain```
# * ```Rain_L7DAYS```
# * ```Rain_L6DAYS```
# * ```Rain_L5DAYS```
# * ```Rain_L4DAYS```
# * ```Rain_L3DAYS```
# * ```Rain_L2DAYS```
# * ```Rain_L1DAYS```
# * ```Season```
# * ```Rainlag1```
# * ```Rainlag2```
# * ```Rainlag3```
# * ```PElag1```
# * ```PElag2```
# * ```PElag3```
# * ```ANcyc```
# * ```storage```
# * ```Storagelag1```
# * ```(site name) fTemp```
# * ```(site name) fPrecp```
# * ```(site name) cm```
# * ```(site name) stat```
# * ```Restriction level```
# * ```site name```(target)
#
# What we're going to try to predict is the site water demand for a wellington region. We will let Autopilot perform feature engineering, model selection, model tuning, and give us the best candidate model ready to use for inferences.
#
# ---
# ## Setup
#
# _This notebook was created and tested on a ml.m5.large notebook instance._
#
# Let's start by specifying:
#
# - The S3 bucket and prefix to use for training and model data.  This should be within the same region as the Notebook Instance, training, and hosting. The following code will use SageMaker's default S3 bucket (and create one if it doesn't exist).
# - The IAM role ARN used to give training and hosting access to your data. See the documentation for how to create these. The following code will use the SageMaker execution role.

# %% [markdown]
# ## declare functions needed for job scheduling later

# %%
import re

def convert_input_to_output_key(input_key):
    # Split the input key by '/'
    parts = input_key.split('/')
    # Remove the first part 'TransformedInputs'
    parts.pop(0)
    # Remove the last part which is the file name
    parts.pop()
    # Join the remaining parts to form the output key
    output_key = '/'.join(parts)
    return output_key

def extract_number(input_string):
    # Use regular expression to find the number before '.csv'
    match = re.search(r'_(\d+)\.csv$', input_string)
    if match:
        return int(match.group(1))
    else:
        return None

def schedule_job(best_candidate_name, input_chunk_key, output_chunk_key, instance_type, bucket_name):
    # Create a SageMaker session
    sagemaker_session = sagemaker.Session()
    timestamp_suffix = strftime("%Y%m%d-%H%M%S", gmtime())
    chunk_idx = extract_number(input_chunk_key)
    transform_job_name=f'{best_candidate_name}-c{chunk_idx}-' + timestamp_suffix
    print(f"BatchTransformJob ({instance_type}): {transform_job_name} on {input_chunk_key}")
    print(f"BatchTransformJob output: {output_chunk_key}")
    input_prefix = input_chunk_key
    output_prefix = output_chunk_key
    
    response = sm.create_transform_job(
        TransformJobName=transform_job_name, 
        ModelName=best_candidate_name,
        MaxPayloadInMB=20,
        BatchStrategy="MultiRecord",
        ModelClientConfig={
            'InvocationsTimeoutInSeconds': 3600
        },
        TransformInput={
            'DataSource': {
                'S3DataSource': {
                    'S3DataType': 'S3Prefix',
                    'S3Uri': 's3://{}/{}'.format(bucket_name, input_prefix)
                }
            },
            'ContentType': 'text/csv',
            'SplitType': 'Line'
        },
        TransformOutput={
            'S3OutputPath': 's3://{}/{}'.format(bucket_name, output_prefix),
            'AssembleWith': 'Line',
        },
        TransformResources={
            'InstanceType': instance_type, #'ml.c5.4xlarge', 'ml.m5.12xlarge',
            'InstanceCount': 1
        }
        )
    return transform_job_name

def check_job_status(transform_job_name):
    while True:
        describe_response = sm.describe_transform_job(TransformJobName=transform_job_name)
        job_run_status = describe_response["TransformJobStatus"]
        if job_run_status in ("Failed", "Completed", "Stopped"):
            print(f"{datetime.datetime.now()} {describe_response['TransformJobStatus']}")
            break
        print(f"{datetime.datetime.now()} {describe_response['TransformJobStatus']}")
        sleep(60)

def get_job_status(job):
    describe_response = sm.describe_transform_job(TransformJobName=job)
    job_run_status = describe_response["TransformJobStatus"]
    return job_run_status

def schedule_batch_transform_jobs(best_candidate_name, input_chunk_key_list, output_chunk_key_list, instance_types, bucket_name):
    running_jobs = {instance_type: [] for instance_type in instance_types}
    max_parallel_jobs = 4
    input_index = 0

    while input_index < len(input_chunk_key_list):
        for instance_type in instance_types:
            while len(running_jobs[instance_type]) < max_parallel_jobs and input_index < len(input_chunk_key_list):
                # Schedule a new job
                input_chunk_key = input_chunk_key_list[input_index]
                output_chunk_key = output_chunk_key_list[input_index]
                try:
                    transform_job_name = schedule_job(best_candidate_name, input_chunk_key, output_chunk_key, instance_type, bucket_name)
                    running_jobs[instance_type].append(transform_job_name)
                    input_index += 1
                except:
                    print(f"schedule job exception with {instance_type}, switch to the next instance_type")
                    break

        # Check the status of running jobs and remove completed jobs from the list
        all_running_jobs = []
        for instance_type in instance_types:
            for job in running_jobs[instance_type]:
                check_job_status(job)
            job_status_x = [job for job in running_jobs[instance_type] if get_job_status(job) not in ("Failed", "Completed", "Stopped")]
            running_jobs[instance_type] = job_status_x
            all_running_jobs.extend(job_status_x)
        
        if len(all_running_jobs) > 0:
            sleep(60)  # jobs running, Wait before checking again
        else:
            sleep(1)  # no jobs running, don't sleep

    # Wait for all remaining jobs to complete
    for instance_type in instance_types:
        while running_jobs[instance_type]:
            for job in running_jobs[instance_type]:
                check_job_status(job)
            job_status_x = [job for job in running_jobs[instance_type] if get_job_status(job) not in ("Failed", "Completed", "Stopped")]
            running_jobs[instance_type] = job_status_x
            if len(job_status_x) > 0:
                sleep(60)  # jobs running, Wait before checking again
            else:
                sleep(1)  # no jobs running, don't sleep

# %%
from io import StringIO
import boto3

s3 = boto3.client("s3")

def list_csv_files(bucket_name, key_path):
    csv_files = []
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name, Prefix=key_path)
    
    for page in page_iterator:
        if 'Contents' in page:
            for content in page['Contents']:
                if content['Key'].endswith('.csv'):
                    csv_files.append(content['Key'])
    
    return csv_files

def read_csv_files_to_dataframes(bucket_name, csv_files):
    dataframes = []
    for key in csv_files:
        # Get the object from S3
        obj = s3.get_object(Bucket=bucket_name, Key=key)
        # Read the CSV file content
        data = obj['Body'].read().decode('utf-8')
        # Convert to DataFrame
        df = pd.read_csv(StringIO(data))
        dataframes.append(df)
    return dataframes

# %%
# declare all auto_ml_job already completed in Canvas
auto_ml_job_dict = {
    'NorthWellingtonMoa': 'Canvas1734649444174',
    'WellingtonLowLevel': 'Canvas1734648978161',
    'Petone': 'Canvas1733434154045',
    'WellingtonHighWestern': 'Canvas1733085655509',
    'WellingtonHighMoa': 'Canvas1733372214860',
    'NorthWellingtonPorirua': 'Canvas1733369877242',
    'Porirua': 'Canvas1733437572452',
    'Wainuiomata': 'Canvas1734649248674',
    'UpperHutt': 'Canvas1734649294393',
    'LowerHutt': 'Canvas1734649384856'
}

# %% [markdown]
# ### Launching the SageMaker Autopilot Job<a name="Launching"></a>
#
# You can now launch the Autopilot job by calling the `create_auto_ml_job` API.

# %% [markdown]
# To evaluate the model on previously unseen data, we will test it against the test dataset we prepared earlier. For that, we don't necessarily need to deploy the model to an endpoint, we can simply run a batch transform job to get predictions for our unlabeled test dataset.

# %% [markdown]
# # Use models already trained Canvas for Inference

# %% [markdown]
# ## data prep, find simulation folders, find site folders under the respective simulation folder

# %%
import boto3
from io import StringIO

# Initialize the S3 client
s3 = boto3.client('s3')

# Define the S3 bucket and prefix
bucket_name = 'niwa-water-demand-modelling'
prefix = 'Simulation/'

# List objects in the specified S3 path
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Loop through the objects and look for CSV files containing "Final_"
csv_files = []
for obj in response.get('Contents', []):
    key = obj['Key']
    if 'Final_' in key and key.endswith('.csv'):
        csv_files.append(key)

# %%
# Example usage
bucket_name = 'niwa-water-demand-modelling'
key_path = 'TransformedOutputs/Simulation/'
target_files = list_csv_files(bucket_name, key_path)
for key in list(auto_ml_job_dict.keys()):
    key = f"/{key}/"
    key_inputs = [e for e in csv_files if key in e]
    key_files = ["/".join(e.split("/")[1:]) for e in target_files if key in e]
    unfinished = [e for e in key_inputs if e not in key_files]
    print(f"{key}: {len(key_files)}")
    # find out which input file is not covered
    print(f"{key}: {len(unfinished)} files not processed: {unfinished}")
# Out:
# /NorthWellingtonMoa/: 16
# /NorthWellingtonMoa/: 0 files not processed: []
# /WellingtonLowLevel/: 16
# /WellingtonLowLevel/: 0 files not processed: []
# /Petone/: 16
# /Petone/: 0 files not processed: []
# /WellingtonHighWestern/: 16
# /WellingtonHighWestern/: 0 files not processed: []
# /WellingtonHighMoa/: 16
# /WellingtonHighMoa/: 0 files not processed: []
# /NorthWellingtonPorirua/: 16
# /NorthWellingtonPorirua/: 0 files not processed: []
# /Porirua/: 16
# /Porirua/: 0 files not processed: []
# /Wainuiomata/: 16
# /Wainuiomata/: 0 files not processed: []
# /UpperHutt/: 16
# /UpperHutt/: 0 files not processed: []
# /LowerHutt/: 16
# /LowerHutt/: 0 files not processed: []

# %% [markdown]
# ## loop through all sites and their Canvas model, create_model to register the model if needed, find all simulation files for that site, clean up the csv file by only selecting necessary columns, remove the header, and break the file into chunks so that transform jobs can handle. After batch transform job completes, it will save to the destination s3 buckets

# %%
import sagemaker
import boto3
import datetime
from io import StringIO
import io
import pandas as pd
import numpy as np
# from sagemaker.model import Model
from sagemaker import get_execution_role
from time import gmtime, strftime, sleep
from botocore.exceptions import ClientError

role = get_execution_role()
region = boto3.Session().region_name

# Initialize the SageMaker client
sagemaker_client = boto3.client('sagemaker')

# This is the client we will use to interact with SageMaker Autopilot
sm = boto3.Session().client(service_name="sagemaker", region_name=region)

for site_name, auto_ml_job_name in list(auto_ml_job_dict.items())[8:9]:
    # Describe the AutoML job using the V2 API
    # auto_ml_job_name_1 = "Canvas1734649444174"
    response = sagemaker_client.describe_auto_ml_job_v2(AutoMLJobName=auto_ml_job_name)
    
    # Extract the best candidate details
    best_candidate = response['BestCandidate']
    best_candidate_name = best_candidate['CandidateName']
    model_artifacts = best_candidate['InferenceContainers'][0]['ModelDataUrl']
    image_uri = best_candidate['InferenceContainers'][0]['Image']
    best_candidate_containers = best_candidate['InferenceContainers'] 

    # check if model exist
    try:
        response = sm.describe_model(ModelName=best_candidate_name)
        print(f"Model {best_candidate_name} exists. Loading the model.")
    # Load the model logic here
    except ClientError as e:
        if e.response['Error']['Code'] == 'ValidationException':
            print(f"Model {best_candidate_name} does not exist. Creating the model.")
            response = sm.create_model(
                ModelName=best_candidate_name,
                ExecutionRoleArn=role,
                Containers=best_candidate_containers
            )
            print(f"Model {best_candidate_name} created successfully.")
        else:
            print(f"Unexpected error: {e}")

    # Find all s3 paths for input files
    input_files = [e for e in csv_files if site_name in e]
    # Find all s3 paths for output files
    result_files = [e for e in target_files if site_name in e]
            
    for csv_file in input_files:
        # check if input already has output file generate
        result_found = [j for j in result_files if csv_file in j]
        if len(result_found)>0:
            print(f"result found for {csv_file}, continue to next")
            continue
                
        print(f"s3://{bucket_name}/{csv_file}")
        obj = s3.get_object(Bucket=bucket_name, Key=csv_file)
        # Read the CSV file content
        data = obj['Body'].read().decode('utf-8')
        # Convert to DataFrame
        df = pd.read_csv(StringIO(data))
        target = csv_file.split("/")[-1].split(".csv")[0]
        columns = [e for e in df.columns if e not in ["Date", target, "replicate"]]
        
        # Upload the CSV string to S3
        file_name = csv_file.split("/")[-1]
        
        # Split the data into smaller chunks
        chunk_size = 5000  # Adjust the chunk size as needed
        chunks = [df[i:i + chunk_size] for i in range(0, df.shape[0], chunk_size)]

        # Upload the chunks to S3
        input_chunk_key_list = []
        for idx, chunk in enumerate(chunks):
            csv_buffer = StringIO()
            chunk[columns].to_csv(csv_buffer, index=False, header=False)
            chunk_csv_path = csv_file.replace(".csv", f"_{idx}.csv")
            chunk_key = f"TransformedInputs/{chunk_csv_path}"
            s3.put_object(Bucket=bucket_name, Key=chunk_key, Body=csv_buffer.getvalue())
            print(f"Uploaded chunk {idx} to s3://{bucket_name}/{chunk_key}")
            input_chunk_key_list.append(chunk_key)
        # schedule jobs for all chunked csvs
        output_chunk_key_list = []
        for e in input_chunk_key_list:
            output_chunk_key_1 = convert_input_to_output_key(e)
            output_chunk_key = f"TransformedOutputs/{output_chunk_key_1}"
            output_chunk_key_list.append(output_chunk_key)
        instance_types = ['ml.c4.xlarge', 'ml.m4.2xlarge', 'ml.m4.xlarge']
        schedule_batch_transform_jobs(best_candidate_name, input_chunk_key_list, output_chunk_key_list, instance_types, bucket_name)

        # List objects in the specified S3 output path
        # output_chunk_key_list[0]
        output_prefix = output_chunk_key_list[0]
        response = s3.list_objects_v2(Bucket=bucket_name, Prefix=output_prefix)
        
        # Loop through the objects and look for CSV files ends "csv.out"
        output_files = []
        for obj in response.get('Contents', []):
            key = obj['Key']
            if key.endswith('.csv.out'):
                output_files.append(key)
        # concatenate all files and save as csv format to s3
        df_list = []
        for csv_file in sorted(output_files):
            print(f"s3://{bucket_name}/{csv_file}")
            obj = s3.get_object(Bucket=bucket_name, Key=csv_file)
            # Read the CSV file content
            data = obj['Body'].read().decode('utf-8')
            # Convert to DataFrame
            df = pd.read_csv(StringIO(data), names=[file_name.replace(".csv", "")])
            df_list.append(df)
        df_all = pd.concat(df_list, axis=0)
        output_key = f"{output_prefix}/{file_name}"
        csv_buffer = StringIO()
        df_all.to_csv(csv_buffer, index=False)
        s3.put_object(Bucket=bucket_name, Key=output_key, Body=csv_buffer.getvalue())
        print(f"Uploaded merged prediction to s3://{bucket_name}/{output_key}")
# Out:
# Model Canvas1734649294393-trial-t1-1 exists. Loading the model.
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250121-231406 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250121-231407 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250121-231408 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250121-231409 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250121-231410 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250121-231411 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250121-231412 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250121-231414 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250121-231415 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250121-231416 on TransformedInputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt
# 2025-01-21 23:14:17.371533 InProgress
# 2025-01-21 23:15:17.485225 InProgress
# 2025-01-21 23:16:17.595264 InProgress
# 2025-01-21 23:17:17.706793 InProgress
# 2025-01-21 23:18:17.833379 InProgress
# 2025-01-21 23:19:17.944530 InProgress
# 2025-01-21 23:20:18.055625 Completed
# 2025-01-21 23:20:18.085771 Completed
# 2025-01-21 23:20:18.111782 Completed
# 2025-01-21 23:20:18.140352 Completed
# 2025-01-21 23:20:18.263237 Completed
# 2025-01-21 23:20:18.290029 Completed
# 2025-01-21 23:20:18.314570 Completed
# 2025-01-21 23:20:18.340051 Completed
# 2025-01-21 23:20:18.464978 InProgress
# 2025-01-21 23:21:18.568916 Completed
# 2025-01-21 23:21:18.593054 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250121-232123 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250121-232124 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250121-232125 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250121-232125 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250121-232126 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250121-232130 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250121-232130 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250121-232131 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250121-232135 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250121-232136 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt
# 2025-01-21 23:21:37.772983 InProgress
# 2025-01-21 23:22:37.874374 InProgress
# 2025-01-21 23:23:37.980523 InProgress
# 2025-01-21 23:24:38.105231 InProgress
# 2025-01-21 23:25:38.216127 InProgress
# 2025-01-21 23:26:38.334929 InProgress
# 2025-01-21 23:27:38.450663 Completed
# 2025-01-21 23:27:38.490028 Completed
# 2025-01-21 23:27:38.520164 Completed
# 2025-01-21 23:27:38.548291 Completed
# 2025-01-21 23:27:38.680174 Completed
# 2025-01-21 23:27:38.710001 Completed
# 2025-01-21 23:27:38.737230 Completed
# 2025-01-21 23:27:38.765092 Completed
# 2025-01-21 23:27:38.899665 InProgress
# 2025-01-21 23:28:39.004420 Completed
# 2025-01-21 23:28:39.035485 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250121-232844 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250121-232845 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250121-232846 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250121-232847 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250121-232848 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250121-232849 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250121-232850 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250121-232850 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250121-232851 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250121-232852 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt
# 2025-01-21 23:28:57.180228 InProgress
# 2025-01-21 23:29:57.291005 InProgress
# 2025-01-21 23:30:57.412203 InProgress
# 2025-01-21 23:31:57.530116 InProgress
# 2025-01-21 23:32:57.644979 InProgress
# 2025-01-21 23:33:57.753706 InProgress
# 2025-01-21 23:34:57.882546 InProgress
# 2025-01-21 23:35:57.989822 InProgress
# 2025-01-21 23:36:58.106584 InProgress
# 2025-01-21 23:37:58.222136 InProgress
# 2025-01-21 23:38:58.346603 InProgress
# 2025-01-21 23:39:58.511720 InProgress
# 2025-01-21 23:40:58.615852 InProgress
# 2025-01-21 23:41:58.731083 Completed
# 2025-01-21 23:41:58.761677 Completed
# 2025-01-21 23:41:58.802728 Completed
# 2025-01-21 23:41:58.834617 Completed
# 2025-01-21 23:41:58.965731 Completed
# 2025-01-21 23:41:58.998013 Completed
# 2025-01-21 23:41:59.026116 Completed
# 2025-01-21 23:41:59.055002 Completed
# 2025-01-21 23:41:59.207223 Completed
# 2025-01-21 23:41:59.238101 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250121-234204 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250121-234204 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250121-234205 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250121-234206 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250121-234207 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250121-234208 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250121-234210 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250121-234211 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250121-234213 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250121-234214 on TransformedInputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt
# 2025-01-21 23:42:15.691678 InProgress
# 2025-01-21 23:43:15.798920 InProgress
# 2025-01-21 23:44:15.911168 InProgress
# 2025-01-21 23:45:16.019724 InProgress
# 2025-01-21 23:46:16.125696 InProgress
# 2025-01-21 23:47:16.231136 InProgress
# 2025-01-21 23:48:16.340246 Completed
# 2025-01-21 23:48:16.365445 Completed
# 2025-01-21 23:48:16.396556 Completed
# 2025-01-21 23:48:16.422666 Completed
# 2025-01-21 23:48:16.535682 Completed
# 2025-01-21 23:48:16.561818 Completed
# 2025-01-21 23:48:16.587827 Completed
# 2025-01-21 23:48:16.614475 Completed
# 2025-01-21 23:48:16.725961 InProgress
# 2025-01-21 23:49:16.829083 Completed
# 2025-01-21 23:49:16.856385 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250121-234922 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250121-234922 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250121-234923 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250121-234926 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250121-234927 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250121-234927 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250121-234929 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250121-234930 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250121-234933 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250121-234933 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt
# 2025-01-21 23:49:34.865742 InProgress
# 2025-01-21 23:50:34.972224 InProgress
# 2025-01-21 23:51:35.094792 InProgress
# 2025-01-21 23:52:35.203683 InProgress
# 2025-01-21 23:53:35.304792 InProgress
# 2025-01-21 23:54:35.418276 InProgress
# 2025-01-21 23:55:35.538057 Completed
# 2025-01-21 23:55:35.565201 Completed
# 2025-01-21 23:55:35.595324 Completed
# 2025-01-21 23:55:35.630026 InProgress
# 2025-01-21 23:56:35.733303 Completed
# 2025-01-21 23:56:35.853106 Completed
# 2025-01-21 23:56:35.885056 Completed
# 2025-01-21 23:56:35.911224 Completed
# 2025-01-21 23:56:35.938171 Completed
# 2025-01-21 23:56:36.058644 Completed
# 2025-01-21 23:56:36.084201 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250121-235641 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250121-235641 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250121-235643 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250121-235645 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250121-235646 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250121-235646 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250121-235647 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250121-235648 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250121-235649 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250121-235651 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt
# 2025-01-21 23:57:01.362557 InProgress
# 2025-01-21 23:58:01.508564 InProgress
# 2025-01-21 23:59:01.634677 InProgress
# 2025-01-22 00:00:01.750713 InProgress
# 2025-01-22 00:01:01.865308 InProgress
# 2025-01-22 00:02:01.973487 InProgress
# 2025-01-22 00:03:02.090282 Completed
# 2025-01-22 00:03:02.142365 Completed
# 2025-01-22 00:03:02.170256 Completed
# 2025-01-22 00:03:02.199150 Completed
# 2025-01-22 00:03:02.324810 Completed
# 2025-01-22 00:03:02.353998 Completed
# 2025-01-22 00:03:02.380872 Completed
# 2025-01-22 00:03:02.405355 Completed
# 2025-01-22 00:03:02.531739 Completed
# 2025-01-22 00:03:02.559301 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250122-000307 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250122-000308 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250122-000309 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250122-000310 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250122-000310 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250122-000312 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250122-000312 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250122-000313 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250122-000315 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250122-000316 on TransformedInputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt
# 2025-01-22 00:03:17.868438 InProgress
# 2025-01-22 00:04:17.980657 InProgress
# 2025-01-22 00:05:18.087347 InProgress
# 2025-01-22 00:06:18.243590 InProgress
# 2025-01-22 00:07:18.348662 InProgress
# 2025-01-22 00:08:18.449668 InProgress
# 2025-01-22 00:09:18.567137 Completed
# 2025-01-22 00:09:18.598042 Completed
# 2025-01-22 00:09:18.625657 Completed
# 2025-01-22 00:09:18.651800 Completed
# 2025-01-22 00:09:18.781596 Completed
# 2025-01-22 00:09:18.807711 Completed
# 2025-01-22 00:09:18.831735 Completed
# 2025-01-22 00:09:18.857636 Completed
# 2025-01-22 00:09:18.980811 Completed
# 2025-01-22 00:09:19.008449 InProgress
# 2025-01-22 00:10:19.119137 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_EC-Earth3_ssp126/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_EC-Earth3_ssp126/UpperHutt/Upper Hutt_0.csv
# ...
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250122-005213 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt
# 2025-01-22 00:52:15.063492 InProgress
# 2025-01-22 00:53:15.173321 InProgress
# 2025-01-22 00:54:15.278350 InProgress
# 2025-01-22 00:55:15.381372 InProgress
# 2025-01-22 00:56:15.489088 InProgress
# 2025-01-22 00:57:15.600712 InProgress
# 2025-01-22 00:58:15.717364 Completed
# 2025-01-22 00:58:15.743501 Completed
# 2025-01-22 00:58:15.771298 Completed
# 2025-01-22 00:58:15.797708 Completed
# 2025-01-22 00:58:15.915185 Completed
# 2025-01-22 00:58:15.939165 Completed
# 2025-01-22 00:58:15.965207 Completed
# 2025-01-22 00:58:15.996541 Completed
# 2025-01-22 00:58:16.114433 Completed
# 2025-01-22 00:58:16.146086 InProgress
# 2025-01-22 00:59:16.257893 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250122-005921 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250122-005921 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250122-005922 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250122-005923 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250122-005924 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250122-005925 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250122-005926 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250122-005927 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250122-005928 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250122-005929 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt
# 2025-01-22 00:59:31.916530 InProgress
# 2025-01-22 01:00:32.020737 InProgress
# 2025-01-22 01:01:32.143391 InProgress
# 2025-01-22 01:02:32.248124 InProgress
# 2025-01-22 01:03:32.350309 InProgress
# 2025-01-22 01:04:32.457915 InProgress
# 2025-01-22 01:05:32.567317 Completed
# 2025-01-22 01:05:32.597665 Completed
# 2025-01-22 01:05:32.624918 Completed
# 2025-01-22 01:05:32.650182 Completed
# 2025-01-22 01:05:32.777261 Completed
# 2025-01-22 01:05:32.802471 Completed
# 2025-01-22 01:05:32.827623 Completed
# 2025-01-22 01:05:32.852252 Completed
# 2025-01-22 01:05:32.975995 Completed
# 2025-01-22 01:05:33.000805 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/UpperHutt/Upper Hutt.csv
# s3://niwa-water-demand-modelling/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt.csv
# Uploaded chunk 0 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_0.csv
# Uploaded chunk 1 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_1.csv
# Uploaded chunk 2 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_2.csv
# Uploaded chunk 3 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_3.csv
# Uploaded chunk 4 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_4.csv
# Uploaded chunk 5 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_5.csv
# Uploaded chunk 6 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_6.csv
# Uploaded chunk 7 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_7.csv
# Uploaded chunk 8 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_8.csv
# Uploaded chunk 9 to s3://niwa-water-demand-modelling/TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c0-20250122-010538 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_0.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c1-20250122-010539 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_1.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c2-20250122-010541 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_2.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.c4.xlarge): Canvas1734649294393-trial-t1-1-c3-20250122-010541 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_3.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c4-20250122-010543 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_4.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c5-20250122-010544 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_5.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c6-20250122-010545 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_6.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.m4.2xlarge): Canvas1734649294393-trial-t1-1-c7-20250122-010546 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_7.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c8-20250122-010546 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_8.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# BatchTransformJob (ml.m4.xlarge): Canvas1734649294393-trial-t1-1-c9-20250122-010549 on TransformedInputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_9.csv
# BatchTransformJob output: TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt
# 2025-01-22 01:05:49.807434 InProgress
# 2025-01-22 01:06:49.916005 InProgress
# 2025-01-22 01:07:50.025024 InProgress
# 2025-01-22 01:08:50.157725 InProgress
# 2025-01-22 01:09:50.272652 InProgress
# 2025-01-22 01:10:50.379624 InProgress
# 2025-01-22 01:11:50.494299 Completed
# 2025-01-22 01:11:50.524626 Completed
# 2025-01-22 01:11:50.553160 Completed
# 2025-01-22 01:11:50.578529 Completed
# 2025-01-22 01:11:50.708798 Completed
# 2025-01-22 01:11:50.738514 Completed
# 2025-01-22 01:11:50.765103 Completed
# 2025-01-22 01:11:50.790405 Completed
# 2025-01-22 01:11:50.908198 Completed
# 2025-01-22 01:11:50.937006 InProgress
# 2025-01-22 01:12:51.057610 Completed
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_0.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_1.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_2.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_3.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_4.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_5.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_6.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_7.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_8.csv.out
# s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt_9.csv.out
# Uploaded merged prediction to s3://niwa-water-demand-modelling/TransformedOutputs/Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/UpperHutt/Upper Hutt.csv

# %% [markdown]
# ## function to concatenate all chunk predictions and join back with datetime in original input file, this is done by site, when data from all sites are concatenated, they will be joined together to form a single output result by experiment

# %%
[e for e in csv_files if site_name in e]
# Out:
# ['Simulation/Final_HydroClimaticFile_ACCESS-CM2_ssp370/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp126/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp245/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_AWI-CM-1-1-MR_ssp370/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp126/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp245/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_CNRM-CM6-1_ssp370/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_EC-Earth3_ssp126/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_EC-Earth3_ssp245/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_EC-Earth3_ssp370/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_GFDL-ESM4_ssp126/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_GFDL-ESM4_ssp245/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_GFDL-ESM4_ssp370/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp126/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp245/NorthWellingtonMoa/North Wellington Moa.csv',
#  'Simulation/Final_HydroClimaticFile_NorESM2-MM_ssp370/NorthWellingtonMoa/North Wellington Moa.csv']

# %% [markdown]
# ---
# ## Cleanup
#
# The Autopilot job creates many underlying artifacts such as dataset splits, preprocessing scripts, or preprocessed data, etc. This code, when un-commented, deletes them.

# %%
s3 = boto3.resource("s3")
s3_bucket = s3.Bucket(bucket)

print(s3_bucket)
job_outputs_prefix = "{}/output/{}".format(prefix, auto_ml_job_name)
print(job_outputs_prefix)

# Delete S3 objects
s3_bucket.objects.filter(Prefix=job_outputs_prefix).delete()

# %% [markdown]
# We then delete all the experiment and model resources created by the Autopilot experiment.

# %%
def cleanup_experiment_resources(experiment_name):
    trials = sm.list_trials(ExperimentName=experiment_name)["TrialSummaries"]
    print("TrialNames:")
    for trial in trials:
        trial_name = trial["TrialName"]
        print(f"\n{trial_name}")

        components_in_trial = sm.list_trial_components(TrialName=trial_name)
        print("\tTrialComponentNames:")
        for component in components_in_trial["TrialComponentSummaries"]:
            component_name = component["TrialComponentName"]
            print(f"\t{component_name}")
            sm.disassociate_trial_component(TrialComponentName=component_name, TrialName=trial_name)
            try:
                # comment out to keep trial components
                sm.delete_trial_component(TrialComponentName=component_name)
            except:
                # component is associated with another trial
                continue
            # to prevent throttling
            time.sleep(5)
        sm.delete_trial(TrialName=trial_name)
    sm.delete_experiment(ExperimentName=experiment_name)
    print(f"\nExperiment {experiment_name} deleted")


def cleanup_autopilot_models(autopilot_job_name):
    print("{0}:\n".format(autopilot_job_name))
    response = sm.list_models(NameContains=autopilot_job_name)

    for model in response["Models"]:
        model_name = model["ModelName"]
        print(f"\t{model_name}")
        sm.delete_model(ModelName=model_name)
        # to prevent throttling
        time.sleep(3)

# %%
cleanup_experiment_resources("{0}-aws-auto-ml-job".format(auto_ml_job_name))

# %%
cleanup_autopilot_models(auto_ml_job_name)

# %% [markdown]
# Finally, the following code, when uncommented, will delete the local files used in this demo.

# %%
import shutil
import glob
import os


def delete_local_files():
    base_path = ""
    dir_list = glob.iglob(os.path.join(base_path, "{0}*".format(auto_ml_job_name)))

    for path in dir_list:
        if os.path.isdir(path):
            shutil.rmtree(path)

    if os.path.exists("CaliforniaHousing"):
        shutil.rmtree("CaliforniaHousing")

    if os.path.exists("cal_housing.tgz"):
        os.remove("cal_housing.tgz")

    if os.path.exists("SageMakerAutopilotCandidateDefinitionNotebook.ipynb"):
        os.remove("SageMakerAutopilotCandidateDefinitionNotebook.ipynb")

    if os.path.exists("SageMakerAutopilotDataExplorationNotebook.ipynb"):
        os.remove("SageMakerAutopilotDataExplorationNotebook.ipynb")

    if os.path.exists("test_data_no_target.csv"):
        os.remove("test_data_no_target.csv")

    if os.path.exists("test_data.csv"):
        os.remove("test_data.csv")

    if os.path.exists("train_data.csv"):
        os.remove("train_data.csv")


## UNCOMMENT TO CLEAN UP LOCAL FILES
# delete_local_files()

# %% [markdown]
# **Note: If you enabled automatic endpoint creation, you will need to delete the endpoint manually.**

# %% [markdown]
# ## Notebook CI Test Results
#
# This notebook was tested in multiple regions. The test results are as follows, except for us-west-2 which is shown at the top of the notebook.
#
# ![This us-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This us-east-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-2/autopilot|autopilot_california_housing.ipynb)
#
# ![This us-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-west-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This ca-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ca-central-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This sa-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/sa-east-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This eu-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This eu-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-2/autopilot|autopilot_california_housing.ipynb)
#
# ![This eu-west-3 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-3/autopilot|autopilot_california_housing.ipynb)
#
# ![This eu-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-central-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This eu-north-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-north-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This ap-southeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-southeast-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This ap-southeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-southeast-2/autopilot|autopilot_california_housing.ipynb)
#
# ![This ap-northeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-northeast-1/autopilot|autopilot_california_housing.ipynb)
#
# ![This ap-northeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-northeast-2/autopilot|autopilot_california_housing.ipynb)
#
# ![This ap-south-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-south-1/autopilot|autopilot_california_housing.ipynb)
